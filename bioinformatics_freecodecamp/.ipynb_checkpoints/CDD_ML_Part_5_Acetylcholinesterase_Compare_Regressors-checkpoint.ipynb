# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 5] Comparing Regressors**
#
# Chanin Nantasenamat
#
# ['Data Professor' YouTube channel](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life data science project that you can include in your data science portfolio. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In Part 5, we will be comparing several ML algorithms for build regression models of acetylcholinesterase inhibitors.

# %% [markdown]
# ## **1. Import libraries**

# %%
! pip install lazypredict
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lazypredict in /home/students/amv6/.local/lib/python3.12/site-packages (0.3.0)
# Requirement already satisfied: click in /home/students/amv6/.local/lib/python3.12/site-packages (from lazypredict) (8.3.3)
# Requirement already satisfied: scikit-learn>=1.0 in /home/students/amv6/.local/lib/python3.12/site-packages (from lazypredict) (1.8.0)
# Requirement already satisfied: pandas>=1.3 in /home/students/amv6/.local/lib/python3.12/site-packages (from lazypredict) (3.0.2)
# Requirement already satisfied: tqdm>=4.0 in /usr/local/bin/miniconda3/lib/python3.12/site-packages (from lazypredict) (4.67.1)
# Requirement already satisfied: joblib>=1.0 in /home/students/amv6/.local/lib/python3.12/site-packages (from lazypredict) (1.5.3)
# Requirement already satisfied: numpy>=1.21 in /home/students/amv6/.local/lib/python3.12/site-packages (from lazypredict) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/students/amv6/.local/lib/python3.12/site-packages (from pandas>=1.3->lazypredict) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.10.0 in /home/students/amv6/.local/lib/python3.12/site-packages (from scikit-learn>=1.0->lazypredict) (1.17.1)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/students/amv6/.local/lib/python3.12/site-packages (from scikit-learn>=1.0->lazypredict) (3.6.0)
# Requirement already satisfied: six>=1.5 in /home/students/amv6/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.3->lazypredict) (1.17.0)

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor

# %% [markdown]
# ## **2. Load the data set**

# %%
# ! wget https://github.com/dataprofessor/data/raw/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv

# %%
df = pd.read_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
X = df.drop('pIC50', axis=1)
Y = df.pIC50

# %% [markdown]
# ## **3. Data pre-processing**

# %%
# Examine X dimension
X.shape
# Out:
# (18, 881)

# %%
# Remove low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)
X.shape
# Out:
# (18, 90)

# %%
# Perform data splitting using 80/20 ratio
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# ## **4. Compare ML algorithms**

# %%
# Defines and builds the lazyclassifier
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
# clf.fit(X_train, X_train, Y_train, Y_train)
models_test,predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)

# %%
models_test
# Out:
#                                Adjusted R-Squared  R-Squared      RMSE  \
# Model
# KernelRidge                              3.351628 -67.197218  5.576990
# GaussianProcessRegressor                 1.645763 -17.727131  2.922484
# PassiveAggressiveRegressor               1.068218  -0.978308  0.949868
# SGDRegressor                             1.058934  -0.709077  0.882871
# BaggingRegressor                         1.057062  -0.654799  0.868739
# MLPRegressor                             1.050305  -0.458844  0.815682
# RandomForestRegressor                    1.048540  -0.407674  0.801249
# DecisionTreeRegressor                    1.047582  -0.379864  0.793295
# Lars                                     1.047582  -0.379864  0.793295
# ExtraTreeRegressor                       1.047582  -0.379864  0.793295
# GradientBoostingRegressor                1.047505  -0.377640  0.792655
# ExtraTreesRegressor                      1.047504  -0.377624  0.792651
# TransformedTargetRegressor               1.047470  -0.376623  0.792363
# LinearRegression                         1.047470  -0.376623  0.792363
# OrthogonalMatchingPursuit                1.045322  -0.314335  0.774229
# LinearSVR                                1.041997  -0.217900  0.745285
# HuberRegressor                           1.041932  -0.216035  0.744714
# Ridge                                    1.041065  -0.190892  0.736975
# PoissonRegressor                         1.037325  -0.082435  0.702615
# NuSVR                                    1.036405  -0.055757  0.693903
# QuantileRegressor                        1.034647  -0.004763  0.676937
# ElasticNet                               1.034485  -0.000072  0.675355
# LassoCV                                  1.034485  -0.000072  0.675355
# LassoLarsCV                              1.034485  -0.000072  0.675355
# DummyRegressor                           1.034485  -0.000072  0.675355
# ElasticNetCV                             1.034485  -0.000072  0.675355
# Lasso                                    1.034485  -0.000072  0.675355
# LarsCV                                   1.034485  -0.000072  0.675355
# HistGradientBoostingRegressor            1.034485  -0.000072  0.675355
# LassoLars                                1.034485  -0.000072  0.675355
# SVR                                      1.034222   0.007573  0.672769
# KNeighborsRegressor                      1.033985   0.014445  0.670436
# RidgeCV                                  1.033642   0.024393  0.667043
# OrthogonalMatchingPursuitCV              1.033544   0.027213  0.666078
# GammaRegressor                           1.033348   0.032898  0.664129
# TweedieRegressor                         1.032897   0.045998  0.659616
# AdaBoostRegressor                        1.029960   0.131148  0.629491
# BayesianRidge                            1.028601   0.170576  0.615042
#
#                                Time Taken
# Model
# KernelRidge                      0.014332
# GaussianProcessRegressor         0.015626
# PassiveAggressiveRegressor       0.018309
# SGDRegressor                     0.018232
# BaggingRegressor                 0.053989
# MLPRegressor                     0.053448
# RandomForestRegressor            0.238413
# DecisionTreeRegressor            0.016178
# Lars                             0.018745
# ExtraTreeRegressor               0.017354
# GradientBoostingRegressor        0.104078
# ExtraTreesRegressor              0.170867
# TransformedTargetRegressor       0.019019
# LinearRegression                 0.016971
# OrthogonalMatchingPursuit        0.018863
# LinearSVR                        0.021708
# HuberRegressor                   0.084349
# Ridge                            0.017511
# PoissonRegressor                 0.029020
# NuSVR                            0.018236
# QuantileRegressor                0.030151
# ElasticNet                       0.018701
# LassoCV                          0.156018
# LassoLarsCV                      0.119431
# DummyRegressor                   0.014969
# ElasticNetCV                     1.192371
# Lasso                            0.017399
# LarsCV                           0.132474
# HistGradientBoostingRegressor    0.095671
# LassoLars                        0.017464
# SVR                              0.017203
# KNeighborsRegressor              0.024678
# RidgeCV                          0.017234
# OrthogonalMatchingPursuitCV      0.025709
# GammaRegressor                   0.021215
# TweedieRegressor                 0.022238
# AdaBoostRegressor                0.038722
# BayesianRidge                    0.019683

# %%
# Performance table of the training set (80% subset)
# predictions_train['
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Performance table of the test set (20% subset)
models_test
# Out:
#                                Adjusted R-Squared  R-Squared      RMSE  \
# Model
# KernelRidge                              3.351628 -67.197218  5.576990
# GaussianProcessRegressor                 1.645763 -17.727131  2.922484
# PassiveAggressiveRegressor               1.068218  -0.978308  0.949868
# SGDRegressor                             1.058934  -0.709077  0.882871
# BaggingRegressor                         1.057062  -0.654799  0.868739
# MLPRegressor                             1.050305  -0.458844  0.815682
# RandomForestRegressor                    1.048540  -0.407674  0.801249
# DecisionTreeRegressor                    1.047582  -0.379864  0.793295
# Lars                                     1.047582  -0.379864  0.793295
# ExtraTreeRegressor                       1.047582  -0.379864  0.793295
# GradientBoostingRegressor                1.047505  -0.377640  0.792655
# ExtraTreesRegressor                      1.047504  -0.377624  0.792651
# TransformedTargetRegressor               1.047470  -0.376623  0.792363
# LinearRegression                         1.047470  -0.376623  0.792363
# OrthogonalMatchingPursuit                1.045322  -0.314335  0.774229
# LinearSVR                                1.041997  -0.217900  0.745285
# HuberRegressor                           1.041932  -0.216035  0.744714
# Ridge                                    1.041065  -0.190892  0.736975
# PoissonRegressor                         1.037325  -0.082435  0.702615
# NuSVR                                    1.036405  -0.055757  0.693903
# QuantileRegressor                        1.034647  -0.004763  0.676937
# ElasticNet                               1.034485  -0.000072  0.675355
# LassoCV                                  1.034485  -0.000072  0.675355
# LassoLarsCV                              1.034485  -0.000072  0.675355
# DummyRegressor                           1.034485  -0.000072  0.675355
# ElasticNetCV                             1.034485  -0.000072  0.675355
# Lasso                                    1.034485  -0.000072  0.675355
# LarsCV                                   1.034485  -0.000072  0.675355
# HistGradientBoostingRegressor            1.034485  -0.000072  0.675355
# LassoLars                                1.034485  -0.000072  0.675355
# SVR                                      1.034222   0.007573  0.672769
# KNeighborsRegressor                      1.033985   0.014445  0.670436
# RidgeCV                                  1.033642   0.024393  0.667043
# OrthogonalMatchingPursuitCV              1.033544   0.027213  0.666078
# GammaRegressor                           1.033348   0.032898  0.664129
# TweedieRegressor                         1.032897   0.045998  0.659616
# AdaBoostRegressor                        1.029960   0.131148  0.629491
# BayesianRidge                            1.028601   0.170576  0.615042
#
#                                Time Taken
# Model
# KernelRidge                      0.017452
# GaussianProcessRegressor         0.016508
# PassiveAggressiveRegressor       0.017974
# SGDRegressor                     0.018083
# BaggingRegressor                 0.055663
# MLPRegressor                     0.054566
# RandomForestRegressor            0.233145
# DecisionTreeRegressor            0.017775
# Lars                             0.020060
# ExtraTreeRegressor               0.018832
# GradientBoostingRegressor        0.108883
# ExtraTreesRegressor              0.175918
# TransformedTargetRegressor       0.017584
# LinearRegression                 0.016806
# OrthogonalMatchingPursuit        0.016886
# LinearSVR                        0.018938
# HuberRegressor                   0.087756
# Ridge                            0.019893
# PoissonRegressor                 0.027949
# NuSVR                            0.018955
# QuantileRegressor                0.027469
# ElasticNet                       0.017939
# LassoCV                          0.156289
# LassoLarsCV                      0.135956
# DummyRegressor                   0.016557
# ElasticNetCV                     1.258387
# Lasso                            0.017419
# LarsCV                           0.128723
# HistGradientBoostingRegressor    0.108990
# LassoLars                        0.017394
# SVR                              0.016666
# KNeighborsRegressor              0.017011
# RidgeCV                          0.020236
# OrthogonalMatchingPursuitCV      0.025794
# GammaRegressor                   0.023030
# TweedieRegressor                 0.018890
# AdaBoostRegressor                0.022923
# BayesianRidge                    0.022903

# %% [markdown]
# ## **5. Data visualization of model performance**

# %%
models_test.columns
# Out:
# Index(['Adjusted R-Squared', 'R-Squared', 'RMSE', 'Time Taken'], dtype='str')

# %%
models_train.columns
# Out:
# Index(['Adjusted R-Squared', 'R-Squared', 'RMSE', 'Time Taken'], dtype='str')

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=models_test.index, x="R-Squared", data=models_test)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=models_test.index, x="RMSE", data=models_test)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=models_test.index, x="Time Taken", data=models_test)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
